# %% [markdown]
# Tutorials of CPS using DLPFC dataset
# ===
# 1. read the dataset
# 2. construct the graph (construct the multi-scale features, option)
# 2. train the model
# 3. generate the arbitrary resolution spots
# 4. visualize the results

# %%
import os,sys
sys.path.append(os.path.realpath(os.path.join(os.getcwd(), '..')))
import warnings
warnings.filterwarnings("ignore")

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import CPS

# %%
opt = CPS.config()
args = opt.parse_args(['--seed', '2025'])
args.dataset_path = '/mnt/d/Dataset/SRT_Dataset/1-DLPFC/'
CPS.set_random_seed(args.seed)
args
# Out:
# Namespace(batch_size=256, clusters=7, coord_dim=2, dataset_path='/mnt/d/Dataset/SRT_Dataset/1-DLPFC/', decoder='MLP', decoder_latent=[256, 512], distill=0.5, dropout=0.2, flow='source_to_target', freq=32, gpu=0, hvgs=3000, inr_latent=[256, 256, 256], k_list=[0, 1, 2, 3, 4, 5, 6, 7], latent_dim=64, lr=0.001, max_epoch=1000, max_neighbors=6, n_spot=0, num_heads=4, prep_scale=True, radius=150, seed=2025, self_loops=True, sigma=10.0, visual=True, weight_decay=0.0001)

# %% [markdown]
# Read the adata

# %%
section = '151676'
adata = sc.read_visium(os.path.join(args.dataset_path+section))
Ann_df = pd.read_csv(os.path.join(args.dataset_path+'1-DLPFC_annotations/', section+'_truth.txt'), 
                     sep='\t', header=None, index_col=0)
Ann_df.columns = ['Ground Truth']
adata.obs['Ground Truth'] = Ann_df.loc[adata.obs_names, 'Ground Truth']
adata
# Out:
# AnnData object with n_obs × n_vars = 3460 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'Ground Truth'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# Preprocess adata

# %%
adata.var_names_make_unique()
sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=args.hvgs)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.scale(adata, zero_center=True, max_value=10)

adata_hvg = adata[:, adata.var['highly_variable']].copy()
adata.obsm['hvg_features'] = adata_hvg.X

# %% [markdown]
# Construct the spatial graph

# %%
spatial_edge = CPS.SpatialGraphBuilder(args)
pyg_data = spatial_edge.build_single_graph(adata, method='rknn')
print(pyg_data.num_nodes, pyg_data.num_genes)
# Out:
# 3460 3000

# %% [markdown]
# Train the CPS model

# %%
trainer = CPS.CPSTrainer(args)
trainer.fit(pyg_data)
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 trainer = CPS.CPSTrainer(args)
# ----> 2 trainer.fit(pyg_data)
#
# File ~/CPS/CPS/cps.py:30, in CPSTrainer.fit(self, pyg_data)
#      28 for _ in tq.tqdm(range(1, self.args.max_epoch)):
#      29     self.optimizer.zero_grad()
# ---> 30     results = self.model(pos, x, edge_index, return_attn=False)
#      31     losses = self.compute_losses(results, x, recon_weight=[0.5, 0.5])
#      32     losses['total'].backward()
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/CPS/CPS/model.py:204, in CPSModel.forward(self, coords, x, edge_index, return_attn)
#     202 def forward(self, coords, x=None, edge_index=None, return_attn=False):
#     203     results = {}
# --> 204     z_teacher, attn_weights = self.teacher(x, edge_index)
#     205     recon_teacher = self.decoder(z_teacher)
#     207     z_student = self.student(coords)
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/CPS/CPS/model.py:127, in TeacherNicheAttention.forward(self, x, edge_index, return_weights)
#     124     scale_features = self.gene_proj(x)  # (N, S, D)
#     126 if self.share_weights:
# --> 127     query = self.query_proj(x).reshape(N, self.num_heads, self.head_dim) # (N, H, D_h)
#     128     keys = self.key_proj(scale_features).reshape(N, self.num_scales, self. num_heads, self.head_dim)
#     129     values = self.value_proj(scale_features).reshape(N, self.num_scales, self. num_heads, self.head_dim)
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/pyg/lib/python3.8/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (3460x3000 and 64x64)

# %% [markdown]
# Downstream analysis
